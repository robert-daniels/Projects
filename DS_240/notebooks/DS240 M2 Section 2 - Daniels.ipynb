# %% [markdown]
# Mid Term Exam 2 - Section 2: Robert Daniels
# 04/21/2022

# %% [markdown]
# Section 2: Q1

# %%
import pandas as pd

# %%
df = pd.read_csv('accidental_drug_related_deaths.csv', index_col=0)

# %% [markdown]
# Section 2: Q2

# %%
df.head(3)
# Out:
#                    Date      DateType   Age  Gender   Race ResidenceCity  \
# ID
# 14-0273  6/28/2014 0:00  DateReported   NaN     NaN    NaN           NaN
# 13-0102  3/21/2013 0:00   DateofDeath  48.0    Male  Black       NORWALK
# 16-0165  3/13/2016 0:00   DateofDeath  30.0  Female  White    SANDY HOOK
#
#         ResidenceCounty ResidenceState DeathCity DeathCounty  Location  \
# ID
# 14-0273             NaN            NaN       NaN         NaN       NaN
# 13-0102             NaN            NaN   NORWALK   FAIRFIELD  Hospital
# 16-0165       FAIRFIELD             CT   DANBURY         NaN  Hospital
#
#         DescriptionofInjury                                    COD  \
# ID
# 14-0273           substance   Acute fent, hydrocod, benzodiazepine
# 13-0102                 NaN                   Cocaine Intoxication
# 16-0165     Substance Abuse  Acute Heroin and Cocaine Intoxication
#
#         MannerofDeath
# ID
# 14-0273      Accident
# 13-0102      Accident
# 16-0165      Accident

# %% [markdown]
# Section 2: Q3

# %%
df.tail(7)
# Out:
#                    Date      DateType   Age  Gender   Race  ResidenceCity  \
# ID
# 14-0166  4/17/2014 0:00   DateofDeath  56.0    Male  White       PLYMOUTH
# 15-0013   1/7/2015 0:00  DateReported  45.0  Female  White      WATERBURY
# 15-0466   9/8/2015 0:00  DateReported  43.0    Male  White       CHESHIRE
# 17-0618  7/22/2017 0:00  DateReported  21.0    Male  White        MADISON
# 18-0646  8/14/2018 0:00   DateofDeath  30.0    Male  White  LAWRENCEVILLE
# 14-0124  3/16/2014 0:00   DateofDeath  33.0    Male  White       HARTFORD
# 16-0637  9/15/2016 0:00   DateofDeath  33.0    Male  White      THOMASTON
#
#         ResidenceCounty ResidenceState  DeathCity DeathCounty   Location  \
# ID
# 14-0166             NaN            NaN   PLYMOUTH  LITCHFIELD  Residence
# 15-0013       NEW HAVEN             CT  WATERBURY   NEW HAVEN  Residence
# 15-0466       NEW HAVEN             CT   CHESHIRE   NEW HAVEN  Residence
# ...

# %% [markdown]
# Section 2: Q4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5105 entries, 14-0273 to 16-0637
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 5103 non-null   object
#  1   DateType             5103 non-null   object
#  2   Age                  5102 non-null   float64
#  3   Gender               5099 non-null   object
#  4   Race                 5092 non-null   object
#  5   ResidenceCity        4932 non-null   object
#  6   ResidenceCounty      4308 non-null   object
#  7   ResidenceState       3556 non-null   object
#  8   DeathCity            5100 non-null   object
#  9   DeathCounty          4005 non-null   object
#  10  Location             5081 non-null   object
#  11  DescriptionofInjury  4325 non-null   object
#  12  COD                  5105 non-null   object
#  13  MannerofDeath        5095 non-null   object
# dtypes: float64(1), object(13)
# memory usage: 598.2+ KB

# %% [markdown]
# Section 2: Q5

# %%
df.rename(columns={
    'DescriptionofInjury': 'InjuryDescription'
}, inplace=True)

# %% [markdown]
# Section 2: Q6

# %%
df.columns = [col.lower() for col in df]

# %% [markdown]
# Section 2: Q7

# %%
df.isnull().sum()
# Out:
# date                    2
# datetype                2
# age                     3
# gender                  6
# race                   13
# residencecity         173
# residencecounty       797
# residencestate       1549
# deathcity               5
# deathcounty          1100
# location               24
# injurydescription     780
# cod                     0
# mannerofdeath          10
# dtype: int64

# %% [markdown]
# Section 2: Q8

# %%
age_mean = df['age'].mean()
print(f"The raw average of the age column is {age_mean}.")
# Out:
# The raw average of the age column is 41.96491571932575.

# %% [markdown]
# Section 2: Q9

# %%
df['Average Age'] = age_mean

# %% [markdown]
# Section 2: Q10

# %%
df[df['location'] == 'Hospital']
# Out:
#                     date      datetype   age  gender             race  \
# ID
# 13-0102   3/21/2013 0:00   DateofDeath  48.0    Male            Black
# 16-0165   3/13/2016 0:00   DateofDeath  30.0  Female            White
# 16-0208   3/31/2016 0:00   DateofDeath  23.0    Male            White
# 13-0052   2/13/2013 0:00   DateofDeath  22.0    Male     Asian, Other
# 13-0404  11/10/2013 0:00   DateofDeath  40.0  Female            White
# ...                  ...           ...   ...     ...              ...
# 17-0242   3/22/2017 0:00  DateReported  58.0  Female            White
# 12-0222   8/27/2012 0:00   DateofDeath  71.0    Male  Hispanic, White
# 15-0508   9/28/2015 0:00  DateReported  21.0    Male            White
# 16-0043   1/21/2016 0:00   DateofDeath  29.0    Male            White
# 17-0618   7/22/2017 0:00  DateReported  21.0    Male            White
#
#         residencecity residencecounty residencestate    deathcity deathcounty  \
# ID
# ...
